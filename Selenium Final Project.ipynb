# %%
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from selenium import webdriver
import pandas as pd
import time


webdriver_service = Service('path/to/chromedriver')  # Replace with the path to your chromedriver executable
webdriver_options = Options()
driver = webdriver.Chrome(service=webdriver_service, options=webdriver_options)
driver.get("https://webscraper.io/test-sites/e-commerce/static/")

time.sleep(2)

open_link = driver.find_element(By.XPATH, '//*[@id="side-menu"]/li[3]/a')
open_link.click()

time.sleep(2)

click_laptop = driver.find_element(By.XPATH, '//*[@id="side-menu"]/li[3]/ul/li[2]/a')
click_laptop.click()

time.sleep(2)

base_url = "https://webscraper.io/test-sites/e-commerce/static/computers/laptops?"
end_url = "page="
num_pages = int(input("Enter the Page Number : "))


for page in range(1, num_pages + 1):
    url = base_url.format(page)
    driver.get(url)
    
    All_boxes_link = driver.find_elements(By.CLASS_NAME, "thumbnail")
    
    all_page_lst = []
    name_list = []
    price_list=[]
    description_list=[]
    rating_list=[]
    for box in All_boxes_link:
        name = box.find_element(By.CLASS_NAME, "title").text.strip()
        price = box.find_element(By.CLASS_NAME, "price").text.strip()
        description = box.find_element(By.CLASS_NAME, "description").text.strip()
        rating = box.find_element(By.CLASS_NAME, "ratings").text
#         swatches = box.find_element(By.CLASS_NAME, "swatches").text
        

        print("Name:", name)
        print("Price:", price)
        print("Description:", description)
        print("Rating:", rating)
#         print("Swatches",swatches)
        print()
        
        name_list.append(name)
        price_list.append(price)
        description_list.append(description)
        rating_list.append(rating)


        all_page_info = {
            "Name": name_list,
            "Price": price_list,
            "Description": description_list,
            "Rating": rating_list}
        
        all_page_lst.append(all_page_info)
        print(all_page_lst)
# Out:
# Enter the Page Number : 5
# Name: Packard 255 G2
# Price: $416.99
# Description: 15.6", AMD E2-3800 1.3GHz, 4GB, 500GB, Windows 8.1
# Rating: 2 reviews
#
# [{'Name': ['Packard 255 G2'], 'Price': ['$416.99'], 'Description': ['15.6", AMD E2-3800 1.3GHz, 4GB, 500GB, Windows 8.1'], 'Rating': ['2 reviews']}]
# Name: Aspire E1-510
# Price: $306.99
# Description: 15.6", Pentium N3520 2.16GHz, 4GB, 500GB, Linux
# Rating: 2 reviews
#
# [{'Name': ['Packard 255 G2', 'Aspire E1-510'], 'Price': ['$416.99', '$306.99'], 'Description': ['15.6", AMD E2-3800 1.3GHz, 4GB, 500GB, Windows 8.1', '15.6", Pentium N3520 2.16GHz, 4GB, 500GB, Linux'], 'Rating': ['2 reviews', '2 reviews']}, {'Name': ['Packard 255 G2', 'Aspire E1-510'], 'Price': ['$416.99', '$306.99'], 'Description': ['15.6", AMD E2-3800 1.3GHz, 4GB, 500GB, Windows 8.1', '15.6", Pentium N3520 2.16GHz, 4GB, 500GB, Linux'], 'Rating': ['2 reviews', '2 reviews']}]
# Name: ThinkPad T540p
# Price: $1178.99
# ...

# %%
df = pd.DataFrame(all_page_lst)
df
# Out:
#                                                 Name  \
# 0  [Packard 255 G2, Aspire E1-510, ThinkPad T540p...
# 1  [Packard 255 G2, Aspire E1-510, ThinkPad T540p...
# 2  [Packard 255 G2, Aspire E1-510, ThinkPad T540p...
# 3  [Packard 255 G2, Aspire E1-510, ThinkPad T540p...
# 4  [Packard 255 G2, Aspire E1-510, ThinkPad T540p...
# 5  [Packard 255 G2, Aspire E1-510, ThinkPad T540p...
#
#                                                Price  \
# 0  [$416.99, $306.99, $1178.99, $739.99, $1311.99...
# 1  [$416.99, $306.99, $1178.99, $739.99, $1311.99...
# 2  [$416.99, $306.99, $1178.99, $739.99, $1311.99...
# 3  [$416.99, $306.99, $1178.99, $739.99, $1311.99...
# 4  [$416.99, $306.99, $1178.99, $739.99, $1311.99...
# 5  [$416.99, $306.99, $1178.99, $739.99, $1311.99...
#
#                                          Description  \
# 0  [15.6", AMD E2-3800 1.3GHz, 4GB, 500GB, Window...
# 1  [15.6", AMD E2-3800 1.3GHz, 4GB, 500GB, Window...
# ...

# %%
df['Name'][1]
# Out:
# ['Packard 255 G2',
#  'Aspire E1-510',
#  'ThinkPad T540p',
#  'ProBook',
#  'ThinkPad X240',
#  'Aspire E1-572G']

# %%
df.to_excel('all_page_lst.xlsx')

# %%
all_page_info
# Out:
# {'Name': ['ThinkPad Yoga',
#   'Pavilion',
#   'Inspiron 15',
#   'Dell XPS 13',
#   'ThinkPad X230',
#   'HP 250 G3'],
#  'Price': ['$1033.99',
#   '$609.99',
#   '$745.99',
#   '$1281.99',
#   '$1244.99',
#   '$520.99'],
#  'Description': ['12.5" Touch, Core i3-4010U, 4GB, 500GB + 16GB SSD Cache,',
#   '15.6", Core i5-4200U, 6GB, 750GB, Windows 8.1',
#   'Moon Silver, 15.6", Core i7-4510U, 8GB, 1TB, Radeon HD R7 M265 2GB,',
#   '13.3" Touch, Core i5-4210U, 8GB, 128GB SSD, Windows 8.1',
#   '12.5", Core i5 2.6GHz, 8GB, 180GB SSD, Win7 Pro 64bit',
#   '15.6", Core i5-4210U, 4GB, 500GB, Windows 8.1'],
#  'Rating': ['13 reviews',
#   '4 reviews',
#   '12 reviews',
#   '4 reviews',
#   '10 reviews',
#   '13 reviews']}

# %%
df = pd.DataFrame(all_page_info)

# %%
df
# Out:
#             Name     Price                                        Description  \
# 0  ThinkPad Yoga  $1033.99  12.5" Touch, Core i3-4010U, 4GB, 500GB + 16GB ...
# 1       Pavilion   $609.99      15.6", Core i5-4200U, 6GB, 750GB, Windows 8.1
# 2    Inspiron 15   $745.99  Moon Silver, 15.6", Core i7-4510U, 8GB, 1TB, R...
# 3    Dell XPS 13  $1281.99  13.3" Touch, Core i5-4210U, 8GB, 128GB SSD, Wi...
# 4  ThinkPad X230  $1244.99  12.5", Core i5 2.6GHz, 8GB, 180GB SSD, Win7 Pr...
# 5      HP 250 G3   $520.99      15.6", Core i5-4210U, 4GB, 500GB, Windows 8.1
#
#        Rating
# 0  13 reviews
# 1   4 reviews
# 2  12 reviews
# 3   4 reviews
# 4  10 reviews
# 5  13 reviews

# %%
all_urls[15]
# Out:
# 'https://webscraper.io/test-sites/e-commerce/static/computers/laptops?page=16'

# %%
base_url = "https://webscraper.io/test-sites/e-commerce/static/computers/laptops?"
end_url = "page="
# num_pages = int(input("Enter the Page Number : "))
all_urls = []   # Taking a empty list.

for i in range(1,41):   # Using for loop to append all the URLS into empty list.
    all_urls.append(base_url + end_url + str(i) )
    print(all_urls)
# Out:
# ['https://webscraper.io/test-sites/e-commerce/static/computers/laptops?page=1']
# ['https://webscraper.io/test-sites/e-commerce/static/computers/laptops?page=1', 'https://webscraper.io/test-sites/e-commerce/static/computers/laptops?page=2']
# ['https://webscraper.io/test-sites/e-commerce/static/computers/laptops?page=1', 'https://webscraper.io/test-sites/e-commerce/static/computers/laptops?page=2', 'https://webscraper.io/test-sites/e-commerce/static/computers/laptops?page=3']
# ['https://webscraper.io/test-sites/e-commerce/static/computers/laptops?page=1', 'https://webscraper.io/test-sites/e-commerce/static/computers/laptops?page=2', 'https://webscraper.io/test-sites/e-commerce/static/computers/laptops?page=3', 'https://webscraper.io/test-sites/e-commerce/static/computers/laptops?page=4']
# ...

# %%
https://www.timesjobs.com/candidate/job-search.html?searchType=Home_Search&from=submit
&asKey=OFF&txtKeywords=&cboPresFuncArea=35

# %%
https://www.timesjobs.com/candidate/job-search.html?from=submit&searchType=Home_Search&
    luceneResultSize=25&postWeek=60&cboPresFuncArea=35&pDate=Y&sequence=2&startPage=1
